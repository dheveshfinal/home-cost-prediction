# %%
import pandas as pd
housing=pd.read_csv('C:/Users/dheve/OneDrive/Desktop/ML-project/data.csv')
housing
# Out:
#         CRMI    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing.head()
# Out:
#       CRMI    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.size
# Out:
# 7084

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRMI     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#              CRMI          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
import matplotlib.pyplot as plt
housing.hist(bins=50,figsize=(18,20))
plt.show()

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)
print("no of row in train_set",len(train_set),"\nno of row in test_set",len(test_set))
# Out:
# no of row in train_set 404
# no of row in test_set 102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)#n_splits only one split
for train_index,test_index in split.split(housing,housing['CHAS']):
    strat_train_set=housing.loc[train_index]
    strat_test_set=housing.loc[test_index]

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    376
# 1     28
# Name: count, dtype: int64

# %%
train_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    375
# 1     29
# Name: count, dtype: int64

# %%
376/28
# Out:
# 13.428571428571429

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    95
# 1     7
# Name: count, dtype: int64

# %%
97/7
# Out:
# 13.857142857142858

# %%
##corelation b/w dataset 
corelation=housing.corr()
corelation['MEDV'].sort_values(ascending=False)
##RM is incresing with MEDV (strongly corelated)
# Out:
# MEDV       1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRMI      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attribute=['MEDV','RM','ZN','LSTAT']
scatter_matrix(housing[attribute],figsize=(10,8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind='scatter', x='RM', y='MEDV', alpha=0.8)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
housing.shape
# Out:
# (506, 14)

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy="median")#we are calculating the median of each coloum 
#store the statistics of median in imputer object
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.56510e-01, 0.00000e+00, 9.69000e+00, 0.00000e+00, 5.38000e-01,
#        6.20850e+00, 7.75000e+01, 3.20745e+00, 5.00000e+00, 3.30000e+02,
#        1.90500e+01, 3.91440e+02, 1.13600e+01, 2.12000e+01])

# %%
x=imputer.transform(housing)#fitting those median in the missing value in the housing table

# %%
housing_imputed = pd.DataFrame(x, columns=housing.columns)#This line converts the NumPy array x back into a Pandas DataFrame.

# %%
housing_imputed.describe()
# Out:
#              CRMI          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## scikit-learn design

# %%
#three type of object
#1.Estimator-it estimate some parameter based on dataset.eg imputer
#2.tranformers- takes input and give output based on the learning from fit()
#3.predictor-LinearRegression

# %%
#feature scaling method
#1.min-max scalling-(value - min)/max - min(scale down the value in a range),sklearn->MinMaxScaler
#2.standardization-(value - mean)/std - sklearn class StandardScalar

# %%
from sklearn.pipeline import Pipeline#combine different preprocessing steps and model training into a single
from sklearn.preprocessing import StandardScaler# For example, a feature like "age" might range from 0 to 100, while "income" could range from 30,000 to 200,000. Standardizing ensures that all features contribute equally to the distance calculations used in algorithms like KNN, SVM, or gradient descent optimization.
my_pipeline=Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scalar',StandardScaler())
])

# %%
housing_num_ur=my_pipeline.fit_transform(housing)

# %%
housing_num_ur
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %% [markdown]
# ## Selecting desired model

# %%
housing=strat_train_set.drop("MEDV",axis=1)
housing_label = strat_train_set["MEDV"].copy()
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(housing_num_ur,housing_label)
# Out:
# LinearRegression()

# %%
some_data=housing.iloc[:5]
some_labels=housing_label.iloc[:5]
prepaired_data=my_pipeline.transform(some_data)

# %%
model.predict(prepaired_data)
# Out:
# array([23.94996893, 27.21690623, 20.58079789, 25.04088721, 23.76177838])

# %%
list(some_labels)#compair
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
housing_prediction=model.predict(housing_num_ur)
lin_mse=mean_squared_error(housing_label,housing_prediction)
lin_mse#which is very less so change the model
rmse=np.sqrt(lin_mse)
lin_mse
# Out:
# 23.322346079233675

# %%
rmse
# Out:
# 4.829321492635759

# %%
#in desicion tree its giving 0.0 which is overfitting

# %% [markdown]
# ## cross validation

# %%
# mean each time we are changeing the model to find better fit

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,housing_num_ur,housing_label,scoring="neg_mean_squared_error",cv=10)
rmse_scores=np.sqrt(-scores)
rmse_scores#decision tree has less error than this so decision tree is better
# Out:
# array([4.21674442, 4.26026816, 5.1071608 , 3.82881892, 5.34093789,
#        4.3785611 , 7.47384779, 5.48226252, 4.14885722, 6.0669122 ])

# %%
#from sklearn.tree import DecisionTreeRegressor
or
#from sklearn.ensemble import RandomForestRegressor
